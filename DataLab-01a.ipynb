# %% [markdown]
# # Data Lab 1a
#
# Logistics
# 1. Where to run jupyter notebooks?
#     - notebook hub
#     - on your laptop
# 2. How to turn in homework
# 3. ???

# %% [markdown]
# ### 1. Where to run jupyter notebooks?
#
# Jupyter hub provided at https://apma4990.columbiajupyter2.org/
#
# Let's try it out 🤞

# %% [markdown]
# ### 2. What about running things on your laptop?
# ![](https://imgs.xkcd.com/comics/python_environment.png)
#
# Not that hard but it can become extremely hard to provide support to different environments
# 1. Install `conda`
#     - On a mac, this worked for me in a terminal. There are likely other methods.
# ```
# curl https://repo.continuum.io/miniconda/Miniconda3-latest-MacOSX-x86_64.sh -o ~/Downloads/Miniconda3-latest-MacOSX-x86_64.sh
# sh ~/Downloads/Miniconda3-latest-MacOSX-x86_64.sh
# source ~/.bash_profile
# conda update -n base conda
# ```
#     - Linux, use your package manager
# 2. Get an environment.yml file maybe this one https://github.com/mktippett/ENSO-math-environment/blob/master/environment.yml or remove the version requirements
# 3. 'conda env create -f environment.yml'
# 4. `conda activate pangeo`
# 5. `jupyter lab --no-browser`

# %% [markdown]
# ### 3. Download a github repository to your jupyter hub
# `nbgitpuller` is a convenient way. Not required.
#
# I don't have much experience with this. It does seem handy to get a github repos into your hub.
#
# https://jupyterhub.github.io/nbgitpuller/
#
# Create a url that points to a github repository here:
# https://jupyterhub.github.io/nbgitpuller/link.html
#
# Here is the link for this class:
# https://apma4990.columbiajupyter2.org/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fmktippett%2FENSO-math&urlpath=tree%2FENSO-math&branch=master
#     - Click it
#
# Add these repositories too.
# 1. https://github.com/mspieg/intro-numerical-methods
# 2. https://github.com/rabernat/research_computing/tree/master/content/lectures/python The introductory notebooks here
#
# Using these links:
#
# 1. https://apma4990.columbiajupyter2.org/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fmspieg%2Fintro-numerical-methods&urlpath=tree%2Fintro-numerical-methods%2F&branch=master
# 2. https://apma4990.columbiajupyter2.org/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Frabernat%2Fresearch_computing&urlpath=tree%2Fresearch_computing%2F&branch=master
#
# Alternatively you can use the terminal as in what follows.

# %% [markdown]
# ### 4. Homework
# Submit your homework in notebook. The notebook must run in the class jupyterhub environment to avoid problems with incompatable environments.
#
# You will submit your homework via githib.

# %% [markdown]
# ### 4.1 How to get your homework from jupyterhub into github.
#
# Step 0 Get a github account.
#
# Step 1 create a new repo on github with this name BUT WITH YOUR uni
#
# `apma4990-mkt14`
#
# (click on green button)
#
# Back to the jupyterhub. Click on the "+" sign and open a terminal. In what follows, replace `mkt14` with your uni.
#
# Make a directory for your homework
# ```
# jovyan@jupyter-mkt14-40columbia-2eedu:~$ mkdir apma4990-mkt14
# jovyan@jupyter-mkt14-40columbia-2eedu:~$ cd apma4990-mkt14
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$
# ```
#
# Tell git who you are BUT WITH YOUR information
# ```
# jovyan@jupyter-mkt14-40columbia-2eedu:~$ git config --global user.email "mktippett@gmail.com"
# jovyan@jupyter-mkt14-40columbia-2eedu:~$ git config --global user.name "mktippett"
# ```
# Make a file to add
#
# ```
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$ echo "# testing123" >> README.md
# ```
#
# An "only the first time" command (?)
# ```
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$ git init
# Initialized empty Git repository in /home/jovyan/apma4990-mkt14/.git/
# ```
#
# The two of the three git commands that I know
#
# ```
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$ git add README.md
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$ git commit -m "first commit"
# [master (root-commit) 48f82b6] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
#  ```
# Two more "only the first time" commands (?)
# ```
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$ git branch -M master
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$ git remote add origin https://github.com/mktippett/apma4990-mkt14
# ```
# The third of the three commands
# ```
# jovyan@jupyter-mkt14-40columbia-2eedu:~/apma4990-mkt14$ git push -u origin master
# Username for 'https://github.com': mktippett
# Password for 'https://mktippett@github.com':
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 220 bytes | 220.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/mktippett/apma4990-mkt14
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# ```
# The three git commands:
# ```
# git add <file>
# git commit
# git push -u origin master
# ```

# %% [markdown]
# 1. Put your homework in a notebook named 'apma-4990-hw-01.ipynb' (for the first homework, change for the second etc.)
# 2. Add, commit, and push to github
# 3. Tag the version that you want me to look at as v1.0.0
#     - `git tag v1.0.0`
#     - `git push -u origin master --tags`
# 4. At least the first time, submit a link to the github file/repo in canvas

# %% [markdown]
# ### 5. Assignment 1
# 1. Run the following command in a terminal on your jupyterhub server.
# `conda install -c conda-forge nc-time-axis`
# 2. Put this code in a python notebook
#
# ```
# import xarray as xr
# from matplotlib import pyplot as plt
# import cftime
#
# # function to help xarray understand months
# def fix_calendar(ds, timevar='T'):
#     if ds[timevar].attrs['calendar'] == '360':
#         ds[timevar].attrs['calendar'] = '360_day'
#     return ds
#
# dl_url = 'http://iridl.ldeo.columbia.edu/'
# ERSSTv5_url = 'SOURCES/.NOAA/.NCDC/.ERSST/.version5/.sst/'
# n34box_url = 'Y/-5/5/RANGEEDGES/X/190/240/RANGEEDGES/[X/Y]average/'
# n34_url = dl_url + ERSSTv5_url + n34box_url + "zlev/removeGRID/yearly-anomalies/dods"
#
# n34_ds = xr.open_dataset(n34_url,decode_times=False)
# n34_ds = fix_calendar(n34_ds)
# n34_ds = xr.decode_cf(n34_ds)
#
# fig, ax = plt.subplots(figsize=(20,5))
# n34_ds.sst.plot();
# ```
# 3. Put the notebook in your github repo `apma4990-<your uni>` following the instructions above.
# 4. Submit the link the repo in courseworks.
